# %%
import os

import kagglehub

if not os.environ.get("KAGGLE_API_TOKEN"):
    raise RuntimeError(
        "KAGGLE_API_TOKEN is not available in this notebook kernel. "
        "Start Jupyter/VS Code from a shell where KAGGLE_API_TOKEN is exported."
    )

print("Kaggle user:", kagglehub.whoami()["username"])

# Download latest version
path = kagglehub.competition_download("arc-prize-2026-arc-agi-3")

print("Path to competition files:", path)
# Out:
# Kaggle credentials successfully validated.
# Kaggle user: zhyoulun
# Path to competition files: /Users/zyl/.cache/kagglehub/competitions/arc-prize-2026-arc-agi-3
