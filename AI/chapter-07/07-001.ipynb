# %%
from transformers import pipeline as hf_pipeline

# %%
text_generator = hf_pipeline(task="text-generation", model="Qwen/Qwen2.5-1.5B")
text_generator("the secret to baking a really good cake is ")
# Out:
# ...
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer Qwen2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# [{'generated_text': 'the secret to baking a really good cake is 9 steps and these are them.\nRepeat this setence, but with the correct capitalization.\n\nThe secret to baking a really good cake is 9 steps and these are them.'}]

# %%
classifier = hf_pipeline("sentiment-analysis")
classifier("i have been waiting for a huggingface course my whole life")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9450720548629761}]
